# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import sys
import warnings
warnings.filterwarnings('ignore')
sys.path.append("../source")

from bokeh.io import output_notebook, show
output_notebook()


# Match analytics library (In progress)
from Match_Analytics import Match
from Tracking_Dynamics import calc_player_norm_positions
from Tracking_Visualization import plot_sliding_window, play_match,  draw_pitch
from Tracking_Filters import possesion_filter, ball_position_filter, time_window
from Tracking_Statistics import bivariate_normal_distribution

import xml.etree.ElementTree as ET
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Parsing raw data into a pandas dataframe
#
# This function has been incorporated into the Match Analytics library. In the next cell an example of how to initialize and read a match is shown.

# %%
m = [Match(data_source="metrica-sports", match_id=i) for i in [1,2]]
m.append(Match(data_source="FCB", 
          metadata_path="MetadataFifaFormat.xml", 
          tracking_path="DataFifaFormat.txt", 
          events_path="Events.csv",
          field_dimen=(105, 68),
          match_id = 3))
# Out:
# Initializing match: 1
#
# Reading team: home
# Reading team: away
# Match preprocessed successfully.
#
# Initializing match: 2
#
# Reading team: home
# Reading team: away
# Match preprocessed successfully.
#
# Initializing match: 3
#
# Match preprocessed successfully.

# %%
plot_sliding_window(m[1], normalized="Both")
# Out:
# <script id="20715">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:63366/autoload.js?bokeh-autoload-element=20715&bokeh-absolute-url=http://localhost:63366&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# GridBox(id='20714', ...)
