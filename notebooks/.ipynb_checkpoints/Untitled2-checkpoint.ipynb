# %%
from bokeh.io import output_notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
sys.path.append("../source")
from Match_Analytics import Match
from Tracking_Dynamics import calc_player_norm_positions
from Tracking_Visualization import plot_sliding_window, plot_match
from Tracking_Filters import possesion_filter, ball_position_filter, time_window
from Tracking_Statistics import bivariate_normal_distribution

# %%
m1 = Match(data_source = 'metrica-sports', match_id = 1, home_color="orange")
m2 = Match(data_source = 'metrica-sports', match_id = 2)
# Out:
# Initializing match: 1
#
# Reading team: home
# Reading team: away
# Filtering dead time...
#
# Match preprocessed successfully.
#
# Initializing match: 2
#
# Reading team: home
# Reading team: away
# Filtering dead time...
#
# Match preprocessed successfully.

# %%
plot_sliding_window(m1)
# Out:
# <script id="1308">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57250/autoload.js?bokeh-autoload-element=1308&bokeh-absolute-url=http://localhost:57250&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
plot_match(m1)
# Out:
# <script id="1483">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57252/autoload.js?bokeh-autoload-element=1483&bokeh-absolute-url=http://localhost:57252&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
m1.tracking_home.iloc[[0]]
# Out:
#        Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1           1      0.04  -52.91308    1.19816 -18.39312 -10.41896 -17.27694
#
#        Home_2_y  Home_3_x  Home_3_y  ...  Away_25_normx  Away_25_normy  \
# Frame                                ...
# 1       0.77316 -20.21738   9.84028  ...       3.845911      -0.280762
#
#        Away_26_normx  Away_26_normy  Away_27_normx  Away_27_normy  \
# Frame
# 1                NaN            NaN            NaN            NaN
#
#        Away_28_normx  Away_28_normy  ball_normx  ball_normy
# Frame
# 1                NaN            NaN    0.621299    0.288789
#
# [1 rows x 146 columns]

# %%
frame = m1.tracking_home.iloc[[600]]
frame.columns = frame.columns.str.rsplit(r'_', 1, expand=True)
source_home = frame.stack(0).droplevel(0).filter(like="ball", axis=0)
source_home['player'] = source_home.index.str.split("_").str[1]

# %%
["hello"] + ["ball"]
# Out:
# ['hello', 'ball']

# %%
m1.tracking_home = m1.tracking_home.reset_index()

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=1500
variable = m1.tracking_home["Home_2_normy"] + m1.tracking_home["Home_1_normy"] + m1.tracking_home["Home_3_normy"] + m1.tracking_home["Home_4_normy"]

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
#plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([15000,30000])
# Out:
# (15000.0, 30000.0)

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=5000
variable = m1.tracking_home["Home_2_normx"] + m1.tracking_home["Home_1_normx"] + m1.tracking_home["Home_3_normx"] + m1.tracking_home["Home_4_normx"]

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([0,80000])
# Out:
# (0.0, 80000.0)

# %%
s1 = [1 for i in range(1000)]
s2 = [2 for i in range(1000)]

# %%
vec = pd.Series(s1+s2)

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=100
variable = vec

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([0,2000])
# Out:
# (0.0, 2000.0)
