# %%
from bokeh.io import output_notebook
from bokeh.io import show
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
sys.path.append("../source")
from Match_Analytics import Match
from Tracking_Dynamics import calc_player_norm_positions
from Tracking_Visualization import plot_sliding_window, play_match,  draw_pitch
from Tracking_Filters import possesion_filter, ball_position_filter, time_window
from Tracking_Statistics import bivariate_normal_distribution

# %%
m1 = Match(data_source = 'metrica-sports', match_id = 1)
# Out:
# Initializing match: 1
#
# Reading team: home
# Reading team: away
# Filtering dead time...
#
# Match preprocessed successfully.

# %%
plot_sliding_window(m1, normalized = "Both")
# Out:
# <script id="1203">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:58729/autoload.js?bokeh-autoload-element=1203&bokeh-absolute-url=http://localhost:58729&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
play_match(m1)
# Out:
# <script id="5072">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:58736/autoload.js?bokeh-autoload-element=5072&bokeh-absolute-url=http://localhost:58736&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
m1.tracking_home.iloc[[3213]]['Time [s]'].iloc[0]-200

# %%
events_df = time_window(m1.events, 0, 200, frame=True)
events_df

# %%
frame = m1.tracking_home.iloc[[600]]
frame.columns = frame.columns.str.rsplit(r'_', 1, expand=True)
source_home = frame.stack(0).droplevel(0).filter(like="Home", axis=0)
source_home['player'] = source_home.index.str.split("_").str[1]
source_home['end_vx'] = source_home['vx']+source_home['x']
source_home['end_vy'] = source_home['vy']+source_home['y']

# %%
source_home

# %%
m1.tracking_home = m1.tracking_home.reset_index()

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=1500
variable = m1.tracking_home["Home_2_normy"] + m1.tracking_home["Home_1_normy"] + m1.tracking_home["Home_3_normy"] + m1.tracking_home["Home_4_normy"]

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
#plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([15000,30000])

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=5000
variable = m1.tracking_home["Home_2_normx"] + m1.tracking_home["Home_1_normx"] + m1.tracking_home["Home_3_normx"] + m1.tracking_home["Home_4_normx"]

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([0,80000])

# %%
s1 = [1 for i in range(1000)]
s2 = [2 for i in range(1000)]

# %%
vec = pd.Series(s1+s2)

# %%
import matplotlib.pyplot as plt

jugador="Home_7_normy"
finestra=100
variable = vec

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(variable,label="orig")
plt.plot(variable.rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(match_1.tracking_home[jugador].rolling(finestra,center=True).mean(),label="mean "+str(finestra))
#plt.plot(3*match_1.tracking_home[jugador].rolling(finestra,center=True).var(),label="var "+str(finestra))
plt.plot(variable-variable.rolling(finestra,center=True).mean(),label="orig-mean "+str(finestra))
plt.plot(10*(variable-variable.rolling(finestra,center=True).mean()).rolling(finestra,center=True).var(),label="var orig-mean "+str(finestra))

plt.legend()
plt.xlim([0,2000])
